# %%
# !pip install rich

# %%
from rich import print

# %%
print("[blue on yellow]Hi My name is Janhvi[/blue on yellow] [yellow on blue]I am a Python Developer[/yellow on blue]")
# Out:
# Hi My name is Janhvi I am a Python Developer

# %%
print("[white on cyan]Hi My name is Janhvi[/white on cyan]")
# Out:
# Hi My name is Janhvi

# %%
print("[red on green]Hi My nam is Janhvi[/red on green]")
# Out:
# Hi My nam is Janhvi
