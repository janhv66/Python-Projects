# %%
# !pip install yt_dlp
# Out:
# Collecting yt_dlp
#   Downloading yt_dlp-2025.10.22-py3-none-any.whl.metadata (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 4.3 MB/s eta 0:00:00
# Downloading yt_dlp-2025.10.22-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 48.4 MB/s eta 0:00:00
# Installing collected packages: yt_dlp
# Successfully installed yt_dlp-2025.10.22

# %%
import yt_dlp
from moviepy.editor import AudioFileClip
import os
# Out:
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning: invalid escape sequence '\d'
#   lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning: invalid escape sequence '\d'
#   rotation_lines = [l for l in lines if 'rotate          :' in l and re.search('\d+$', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('\d+$', rotation_line)
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if event.key is 'enter':

# %%
def main():
    url = input("Enter YouTube video URL: ").strip()

    output_folder = "downloads"
    os.makedirs(output_folder, exist_ok=True)

    ydl_opts = {
        "format": "bestaudio/best",
        "outtmpl": os.path.join(output_folder, "%(title)s.%(ext)s"),
        "quiet": False,
    }

    print("🎬 Downloading audio...")
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=True)
        downloaded_file = ydl.prepare_filename(info)

    base, ext = os.path.splitext(downloaded_file)
    mp3_file = base + ".mp3"

    print("🎧 Converting to MP3...")
    clip = AudioFileClip(downloaded_file)
    clip.write_audiofile(mp3_file)
    clip.close()

    print(f"✅ Conversion complete! File saved as:\n{mp3_file}")

# %%
if __name__ == '__main__':
  main()
# Out:
# Enter YouTube video URL: https://www.youtube.com/watch?v=PGUdWfB8nLg
# 🎬 Downloading audio...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PGUdWfB8nLg
# [youtube] PGUdWfB8nLg: Downloading webpage
# [youtube] PGUdWfB8nLg: Downloading android sdkless player API JSON
# [youtube] PGUdWfB8nLg: Downloading tv client config
# [youtube] PGUdWfB8nLg: Downloading player 65578ad1-main
# [youtube] PGUdWfB8nLg: Downloading tv player API JSON
# [youtube] PGUdWfB8nLg: Downloading web safari player API JSON
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/65578ad1/player_ias.vflset/en_US/base.js
# WARNING: [youtube] PGUdWfB8nLg: nsig extraction failed: Some formats may be missing
#          n = wqBoE9hKxOU6SdS ; player = https://www.youtube.com/s/player/65578ad1/player_ias.vflset/en_US/base.js
#          Please report this issue on  https://github.com/yt-dlp/yt-dlp/issues?q= , filling out the appropriate issue template. Confirm you are on the latest version using  yt-dlp -U
# WARNING: [youtube] PGUdWfB8nLg: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] PGUdWfB8nLg: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] PGUdWfB8nLg: Downloading m3u8 information
# [info] PGUdWfB8nLg: Downloading 1 format(s): 251
# [download] Sleeping 5.00 seconds as required by the site...
# [download] Destination: downloads/Barack Obama's Inspirational Speech with Subtitles ｜｜ One of the best English speeches ever 2023.webm
# [download] 100% of   10.68MiB in 00:00:00 at 26.20MiB/s
# 🎧 Converting to MP3...
# MoviePy - Writing audio in downloads/Barack Obama's Inspirational Speech with Subtitles ｜｜ One of the best English speeches ever 2023.mp3
# MoviePy - Done.
# ✅ Conversion complete! File saved as:
# downloads/Barack Obama's Inspirational Speech with Subtitles ｜｜ One of the best English speeches ever 2023.mp3
