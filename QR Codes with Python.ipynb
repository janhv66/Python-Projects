# %%
# !pip install pyqrcode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36222 sha256=dae7f76217050aeeda6ae7863c7cc9b3c7bbcd22a0a377e35b0ec26396de3558
#   Stored in directory: /root/.cache/pip/wheels/38/e3/f8/8940ce720556414aefb861a143102b931d8327f6eaea5733e8
# Successfully built pyqrcode
# ...

# %%
import pyqrcode
from pyqrcode import QRCode

# %%
s  = "https://github.com/janhv66"

# %%
url = pyqrcode.create(s)

# %%
url.svg("mygithub.svg", scale = 8)
